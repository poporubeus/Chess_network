# %%
import pandas as pd

# %%
data = pd.read_html(r'https://www.365chess.com/tournaments/Paris_1900/26864')[2]
df = pd.DataFrame(data)
df
# Out:
#             White                Black Result  Round          Date  \
# 0         Burn, A             Brody, M    1-0    1.0  May 17, 1900
# 1        Marco, G          Janowski, D    0-1    1.0  May 17, 1900
# 2      Maroczy, G             Mason, J    1-0    1.0  May 17, 1900
# 3     Mortimer, J          Marshall, F    0-1    1.0  May 17, 1900
# 4   Schlechter, C            Lasker, E    0-1    1.0  May 17, 1900
# ..            ...                  ...    ...    ...           ...
# 95  Schlechter, C           Maroczy, G    ½-½   12.2  Jun 13, 1900
# 96        Burn, A         Pillsbury, H    1-0   13.0  Jun 11, 1900
# 97    Janowski, D  Marquez Sterling, M    1-0   13.0  Jun 11, 1900
# 98      Lasker, E          Mortimer, J    1-0   13.0  Jun 11, 1900
# 99    Marshall, F             Rosen, L    1-0   13.0  Jun 11, 1900
#
#                                           Opening  View
# 0                                             NaN   NaN
# ...
